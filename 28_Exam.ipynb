# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt 
from datetime import timedelta
# %matplotlib inline
Kurl = 'https://raw.githubusercontent.com/ferdinjoe/DSA206/main/kanchanaburi_pm25.csv'
Rurl = 'https://raw.githubusercontent.com/ferdinjoe/DSA206/main/rayongmaptaphut_pm25.csv'
Nurl = 'https://raw.githubusercontent.com/ferdinjoe/DSA206/main/narathiwat_pm25.csv'
Kdf = pd.read_csv(Kurl,index_col=0,parse_dates=[0])
Rdf = pd.read_csv(Rurl,index_col=0,parse_dates=[0])
Ndf = pd.read_csv(Nurl,index_col=0,parse_dates=[0])
Adf = pd.read_csv('https://raw.githubusercontent.com/ferdinjoe/DSA206/main/kanchanaburi_pm25.csv','https://raw.githubusercontent.com/ferdinjoe/DSA206/main/rayongmaptaphut_pm25.csv','https://raw.githubusercontent.com/ferdinjoe/DSA206/main/narathiwat_pm25.csv')
PM1_count = Adf.value_counts()
PM1_count.plot(kind='pie')

plt.plot(year,Adf)
plt.plot(PM2.5,Adf)
plt.xlabel('year')
plt.ylabel('PM2.5 level')
plt.title('PM2.5 level in one year')
plt.show()

print('Kdf: mean=%.3f stdv=%.3f' % (mean(Kdf), std(Kdf)))
print('Rdf: mean=%.3f stdv=%.3f' % (mean(Rdf), std(Rdf)))
print('Ndf: mean=%.3f stdv=%.3f' % (mean(Ndf), std(Ndf)))
pyplot.scatter(Kdf, Rdf, Ndf)
pyplot.show()
# Out:
# <AxesSubplot:ylabel='None'>
